# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-05cab038-e2af-4a55-8b4b-386322c403e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05cab038-e2af-4a55-8b4b-386322c403e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from HW1_ver2 import *
import numpy as np

# %%
print("IRIS - regression")
print("Предсказываем Sepal length по остальным признакам")
# Out:
# IRIS - regression
# Предсказываем Sepal length по остальным признакам

# %%
X, y = iris_loader()

y = X[:, 0].astype(float)
X = np.delete(X, 0, axis=1)

test_size=0.2
random_state=None

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

regression = NeuralNetwork(activation_func=sigmoid, activation_derivative=sigmoid_der, optimizer=momentum_sgd, loss_function='mse')

input_size = X_train.shape[1]
output_size = 1

regression.add_layer(input_size, 64)
regression.add_layer(64, 512)
regression.add_layer(512, 1024)
regression.add_layer(1024, 512)
regression.add_layer(512, 128)
regression.add_layer(128, 64)
regression.add_layer(64, output_size, activation_func = linear, activation_derivative = linear_der)

regression.train(X_train, y_train, epochs=200, learning_rate=0.0001, batch_size=32)

y_pred = regression.forward(X_test)

loss = mse_loss(y_test, y_pred)
print(f"Test Loss: {loss:.4f}")

print(f"Predicted values: {y_pred.ravel()}")
print(f"True values: {y_test.ravel()}")
# Out:
# Epoch 0, Loss: 0.2252
# Epoch 10, Loss: 0.0118
# Epoch 20, Loss: 0.0046
# Epoch 30, Loss: 0.0051
# Epoch 40, Loss: 0.0052
# Epoch 50, Loss: 0.0032
# Epoch 60, Loss: 0.0064
# Epoch 70, Loss: 0.0049
# Epoch 80, Loss: 0.0033
# Epoch 90, Loss: 0.0059
# Epoch 100, Loss: 0.0063
# Epoch 110, Loss: 0.0038
# Epoch 120, Loss: 0.0040
# Epoch 130, Loss: 0.0045
# Epoch 140, Loss: 0.0040
# Epoch 150, Loss: 0.0046
# Epoch 160, Loss: 0.0049
# Epoch 170, Loss: 0.0051
# Epoch 180, Loss: 0.0062
# Epoch 190, Loss: 0.0046
# Test Loss: 0.6666
# Predicted values: [5.83356678 5.83356678 5.83356678 5.83356678 5.83356678 5.83356678
#  5.83356678 5.83356678 5.83356678 5.83356678 5.83356678 5.83356678
#  5.83356678 5.83356678 5.83356678 5.83356678 5.83356678 5.83356678
#  5.83356678 5.83356678 5.83356678 5.83356678 5.83356678 5.83356678
#  5.83356678 5.83356678 5.83356678 5.83356678 5.83356678 5.83356678]
# True values: [5.8 4.8 4.9 6.2 5.6 4.4 7.7 5.  6.8 7.  7.3 5.1 5.1 6.9 5.5 5.7 5.5 5.1
# ...

# %%
print("IRIS - classification")
# Out:
# IRIS - classification

# %%
X, y = iris_loader()
y = one_hot_encode(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
classifier = NeuralNetwork(activation_func=relu, activation_derivative=relu_der, optimizer=sign_sgd, loss_function='cross_entropy')

input_size = X_train.shape[1]
output_size = y_train.shape[1]

classifier.add_layer(input_size, 8)
classifier.add_layer(8, output_size)

classifier.train(X_train, y_train, epochs=300, learning_rate=0.0001, batch_size=16)
y_pred = classifier.forward(X_test)

y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

accuracy = np.mean(y_pred_classes == y_test_classes)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 0, Loss: 0.3325
# Epoch 10, Loss: 0.3267
# Epoch 20, Loss: 0.3246
# Epoch 30, Loss: 0.3155
# Epoch 40, Loss: 0.2975
# Epoch 50, Loss: 0.2877
# Epoch 60, Loss: 0.3061
# Epoch 70, Loss: 0.2609
# Epoch 80, Loss: 0.2415
# Epoch 90, Loss: 0.2416
# Epoch 100, Loss: 0.2610
# Epoch 110, Loss: 0.2938
# Epoch 120, Loss: 0.2388
# Epoch 130, Loss: 0.2238
# Epoch 140, Loss: 0.2063
# Epoch 150, Loss: 0.2452
# Epoch 160, Loss: 0.2653
# Epoch 170, Loss: 0.2094
# Epoch 180, Loss: 0.1996
# Epoch 190, Loss: 0.3178
# Epoch 200, Loss: 0.2631
# Epoch 210, Loss: 0.2605
# Epoch 220, Loss: 0.2834
# Epoch 230, Loss: 0.2548
# Epoch 240, Loss: 0.1869
# Epoch 250, Loss: 0.2585
# Epoch 260, Loss: 0.1986
# Epoch 270, Loss: 0.1695
# Epoch 280, Loss: 0.1730
# Epoch 290, Loss: 0.1860
# Accuracy: 60.00%

# %%
print("MNIST - classification")
# Out:
# MNIST - classification

# %%
X,y = mnist_loader()
y = one_hot_encode(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
classifier = NeuralNetwork(activation_func=relu, activation_derivative=relu_der, optimizer=sgd, loss_function='cross_entropy')
input_size = X_train.shape[1]
output_size = y_train.shape[1]
classifier.add_layer(input_size, 128)
classifier.add_layer(128, output_size)

classifier.train(X_train, y_train, epochs=200, learning_rate=0.001, batch_size=32)
y_pred = classifier.forward(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

accuracy = np.mean(y_pred_classes == y_test_classes)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Epoch 0, Loss: 0.0458
# Epoch 10, Loss: 0.0133
# Epoch 20, Loss: 0.0064
# Epoch 30, Loss: 0.0098
# Epoch 40, Loss: 0.0036
# Epoch 50, Loss: 0.0025
# Epoch 60, Loss: 0.0045
# Epoch 70, Loss: 0.0055
# Epoch 80, Loss: 0.0015
# Epoch 90, Loss: 0.0022
# Epoch 100, Loss: 0.0012
# Epoch 110, Loss: 0.0043
# Epoch 120, Loss: 0.0005
# Epoch 130, Loss: 0.0012
# Epoch 140, Loss: 0.0014
# Epoch 150, Loss: 0.0005
# Epoch 160, Loss: 0.0006
# Epoch 170, Loss: 0.0006
# Epoch 180, Loss: 0.0004
# Epoch 190, Loss: 0.0003
# Accuracy: 96.00%
